# %%
# !git clone https://github.com/akioazevedo/spring2026-msba.git
# Out:
# Cloning into 'spring2026-msba'...
# warning: You appear to have cloned an empty repository.

# %%
# %cd spring2026-msba/
# Out:
# /content/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba

# %%
from os import name
# !git switch -c colab-work
from google.colab import drive
drive.mount('/content/drive')
# !git config --global user.name "akioazevedo"
# !git config --global user.email "akioazevedo@gmail.com"
# !find /content -name "hw1.ipynb"
# !cp "/content/drive/MyDrive/Colab Notebooks/hw1.ipynb" .
# !ls
# !git add hw1.ipynb
# !git commit -m "Add HW1 Colab notebook"
# !git push https://akioazevedo:ghp_xxxxxxxxxxxxx@github.com/akioazevedo/spring2026-msba.git colab-work
# Out:
# Switched to a new branch 'colab-work'
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/hw1.ipynb
# /content/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/hw1.ipynb
# /content/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/spring2026-msba/hw1.ipynb
# /content/drive/MyDrive/Colab Notebooks/hw1.ipynb
# hw1.ipynb
# [colab-work (root-commit) f31bb8f] Add HW1 Colab notebook
#  1 file changed, 1 insertion(+)
#  create mode 100644 hw1.ipynb
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf

# Reproducibility
np.random.seed(0)

# Number of observations
n = 50

# Generate p and q
p = np.random.randint(0, 20, size=n)
q = np.random.randint(0, 20, size=n)

# Create DataFrame
df = pd.DataFrame({
    "p": p,
    "q": q
})

# Regression
model = smf.ols("p ~ q", data=df).fit()

# Output
print(model.summary())

# Interpretation of the regression results for p ~ q using the df DataFrame:
# R-squared (0.014): This indicates that 'q' explains a very small proportion (1.4%) of the variance in 'p'.
# This suggests that 'q' is not a strong linear predictor of 'p' in this model.

# Coefficient for 'q' (0.1406): For every one-unit increase in 'q', 'p' is estimated to increase by 0.1406 units.
# However, the P-value for 'q' (0.407) is high (greater than 0.05), which means this coefficient is not statistically significant.
# Therefore, we cannot confidently conclude that there is a linear relationship between 'q' and 'p'.

# Intercept (8.0424): When 'q' is 0, the expected value of 'p' is 8.0424. This intercept is statistically significant (P-value < 0.001).
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      p   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.6999
# Date:                Sat, 17 Jan 2026   Prob (F-statistic):              0.407
# Time:                        20:20:04   Log-Likelihood:                -164.72
# No. Observations:                  50   AIC:                             333.4
# Df Residuals:                      48   BIC:                             337.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.0424      1.713      4.694      0.000       4.597      11.488
# q              0.1406      0.168      0.837      0.407      -0.197       0.478
# ==============================================================================
# Omnibus:                       18.776   Durbin-Watson:                   1.515
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                3.809
# Skew:                           0.162   Prob(JB):                        0.149
# Kurtosis:                       1.687   Cond. No.                         18.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
